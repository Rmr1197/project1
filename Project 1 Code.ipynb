# %% [markdown]
# # Project 1: CTD

# %% [markdown]
# ### Robert Reiten B ME 450

# %% [markdown]
# Coastal Endurance › Oregon Shelf Surface Piercing Profiler Mooring - did not have enough usable data available

# %% [markdown]
# # Axial Base Deep Profiler - Winter

# %% [markdown]
# First importing the data from the CSV file

# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt

dataframe = pd.read_csv("axial base deep winter.csv")

# %% [markdown]
# Designating and calculating variable values

# %%
z = dataframe.pressure
T = dataframe.temp
cond = dataframe.conductivity_millisiemens
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z

# %% [markdown]
# Finding the Number of Dives

# %%
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Graphic for Number of Dives')

# %%
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 0
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
getnumberofdives(z)
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
# Out:
# 2 dives were performed

# %% [markdown]
# Plotting speed of sound profile (SSP) (Depth versus Speed of Sound)

# %%
avg=np.polyfit(z,ssp,11)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Winter');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');

# %% [markdown]
# # Axial Base Deep Profiler - Summer

# %% [markdown]
# First process lines of code condensed below and condensed from now on

# %%
dataframe = pd.read_csv("axial base deep summer.csv") 
z = dataframe.pressure
T = dataframe.temp
cond = dataframe.conductivity_millisiemens
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 0
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
avg=np.polyfit(z,ssp,5)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Summer');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');
# Out:
# 2 dives were performed

# %% [markdown]
# # Axial Base Shallow Profiler - Winter

# %%
dataframe = pd.read_csv("axial base shallow winter.csv") 
z = dataframe.pressure
T = dataframe.temperature
cond = dataframe.conductivity
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 0
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
avg=np.polyfit(z,ssp,5)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Winter');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');
# Out:
# 8 dives were performed

# %% [markdown]
# # Axial Base Shallow Profiler - Summer

# %%
dataframe = pd.read_csv("axial base shallow summer.csv") 
z = dataframe.pressure
T = dataframe.temperature
cond = dataframe.conductivity
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 2
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
avg=np.polyfit(z,ssp,3)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Summer');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');
# Out:
# 2 dives were performed

# %% [markdown]
# # Oregon Offshore Deep - Winter

# %%
dataframe = pd.read_csv("oregon offshore deep winter.csv") 
z = dataframe.pressure
T = dataframe.temp
cond = dataframe.conductivity_millisiemens
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 0
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
avg=np.polyfit(z,ssp,5)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Winter');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');
# Out:
# 12 dives were performed

# %% [markdown]
# # Oregon Offshore Deep - Summer

# %%
dataframe = pd.read_csv("oregon offshore deep summer.csv") 
z = dataframe.pressure
T = dataframe.temp
cond = dataframe.conductivity_millisiemens
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 0
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
avg=np.polyfit(z,ssp,5)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Summer');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');
# Out:
# 2 dives were performed

# %% [markdown]
# # Oregon Offshore Shallow - Winter

# %%
dataframe = pd.read_csv("oregon offshore shallow winter.csv") 
z = dataframe.pressure
T = dataframe.temperature
cond = dataframe.conductivity
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 0
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
avg=np.polyfit(z,ssp,5)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Winter');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');
# Out:
# 6 dives were performed

# %% [markdown]
# # Oregon Offshore Shallow - Summer

# %%
dataframe = pd.read_csv("Oregon Offshore Shallow Summer.csv") 
z = dataframe.pressure
T = dataframe.temperature
cond = dataframe.conductivity
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 0
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
avg=np.polyfit(z,ssp,5)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Summer');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');
# Out:
# 6 dives were performed

# %% [markdown]
# # Oregon Slope Deep - Winter

# %%
dataframe = pd.read_csv("Oregon slope deep winter.csv") 
z = dataframe.pressure
T = dataframe.temp
cond = dataframe.conductivity_millisiemens
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 0
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
avg=np.polyfit(z,ssp,5)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Winter');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');
# Out:
# 1 dives were performed

# %% [markdown]
# # Oregon Slope Deep - Summer

# %%
dataframe = pd.read_csv("Oregon slope deep summer.csv") 
z = dataframe.pressure
T = dataframe.temp
cond = dataframe.conductivity_millisiemens
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 0
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
avg=np.polyfit(z,ssp,5)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Summer');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');
# Out:
# 2 dives were performed

# %% [markdown]
# # Oregon Slope Shallow - Winter

# %%
dataframe = pd.read_csv("Oregon slope shallow winter.csv") 
z = dataframe.pressure
T = dataframe.temperature
cond = dataframe.conductivity
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 0
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
avg=np.polyfit(z,ssp,5)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Winter');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');
# Out:
# 6 dives were performed

# %% [markdown]
# # Oregon Slope Shallow - Summer

# %%
dataframe = pd.read_csv("Oregon slope shallow summer.csv") 
z = dataframe.pressure
T = dataframe.temperature
cond = dataframe.conductivity
S = dataframe.practical_salinity
ssp = 1449.2 + (4.6*T) -0.055*T**2+0.00029*T**3+(1.34 -0.01*T)*(S-35)+0.016*z
Time = dataframe.time
plt.scatter(Time,z, s=0.5)
plt.ylabel("Depth", fontsize=13)
plt.xlabel("Time", fontsize=13)
plt.title("Graphic for Number of Dives", fontsize=18)
def getnumberofdives(depth):
    bottom = max(depth)
    atbottom = False
    divecount = 0
    for i in range(0, len(depth)):
        if(depth[i] > 0.95 * bottom and not atbottom):
            atbottom = True
        if(depth[i] < 0.95 * bottom and atbottom):
            atbottom = False
            divecount +=1
    return divecount
numdives = getnumberofdives(z) 
divestext = "%s dives were performed"%(numdives)
print (divestext)
avg=np.polyfit(z,ssp,5)
avgssp=np.poly1d(avg)(z)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(ssp,z, s=0.5, label='Summer');
ax1.scatter(avgssp,z, s=.2, label='Average')
plt.gca().invert_yaxis();
plt.ylabel("Depth (m)", fontsize=13);
plt.xlabel("Speed of Sound (m/s)", fontsize=13);
plt.title("Speed of Sound Profile", fontsize=18);
plt.legend(loc='upper right');
# Out:
# 6 dives were performed

# %% [markdown]
# # M2M Code

# %%
import requests
url = "https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/RS03AXPS/SF03A/2A-CTDPFA302/streamed/ctdpf_sbe43_sample?beginDT=2019-07-17T22:00:46.000Z&endDT=2019-07-18T22:00:46.000Z&limit=1000&parameters=908,909"
payload = ""
headers = {'authorization': 'Basic T09JQVBJLVdITk9KRTRQUThKN1lOOlRFTVAtVE9LRU4tQUcyWjJNTlRTQ0M4UEo='}
response = requests.request("GET", url, data=payload, headers=headers)
print(response.text)
# Out:
# [
#   {
#     "seawater_pressure_qc_results": 29,
#     "seawater_temperature": 12.457615785319547,
#     "seawater_pressure": 25.733959012596458,
#     "seawater_pressure_qc_executed": 29,
#     "seawater_temperature_qc_results": 29,
#     "seawater_temperature_qc_executed": 29,
#     "pk": {
#       "node": "SF03A",
#       "stream": "ctdpf_sbe43_sample",
#       "subsite": "RS03AXPS",
#       "deployment": 5,
#       "time": 3772389645.454705,
#       "sensor": "2A-CTDPFA302",
#       "method": "streamed"
#     }
#   },
#   {
#     "seawater_pressure_qc_results": 29,
#     "seawater_temperature": 12.458819058840561,
#     "seawater_pressure": 25.47755995845141,
#     "seawater_pressure_qc_executed": 29,
#     "seawater_temperature_qc_results": 29,
#     "seawater_temperature_qc_executed": 29,
#     "pk": {
#       "node": "SF03A",
#       "stream": "ctdpf_sbe43_sample",
#       "subsite": "RS03AXPS",
#       "deployment": 5,
#       "time": 3772389646.4547143,
# ...
